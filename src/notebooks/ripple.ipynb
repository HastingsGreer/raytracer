# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = np.linspace(-1, 1, 50)
y = np.linspace(-1, 1, 50)
x, y = np.meshgrid(x, y)
z = np.sin((np.abs(x)**(1./3) + y) * 12) / 12

# %%
plt.imshow(z, interpolation="none")

# %%
def vec(i, j):
    print x[i, j], y[i, j], z[i, j]

for i in range(49):
    for j in range(49):
        #upper left triangle
        vec(i, j)
        vec(i+1, j)
        vec(i, j+1)
        
        #lower right triangle
        vec(i+1, j)
        vec(i+1, j+1)
        vec(i, j+1)
# Out:
# -1.0 -1.0 0.0
# -1.0 -0.995991983968 0.00400647095779
# -0.995991983968 -1.0 -0.0119347396135
# -1.0 -0.995991983968 0.00400647095779
# -0.995991983968 -0.995991983968 -0.00795576872693
# -0.995991983968 -1.0 -0.0119347396135
# -0.995991983968 -1.0 -0.0119347396135
# -0.995991983968 -0.995991983968 -0.00795576872693
# -0.991983967936 -1.0 -0.0235313401998
# -0.995991983968 -0.995991983968 -0.00795576872693
# -0.991983967936 -0.995991983968 -0.0196607058372
# -0.991983967936 -1.0 -0.0235313401998
# -0.991983967936 -1.0 -0.0235313401998
# -0.991983967936 -0.995991983968 -0.0196607058372
# -0.987975951904 -1.0 -0.0345635428598
# -0.991983967936 -0.995991983968 -0.0196607058372
# -0.987975951904 -0.995991983968 -0.0308779667045
# -0.987975951904 -1.0 -0.0345635428598
# -0.987975951904 -1.0 -0.0345635428598
# -0.987975951904 -0.995991983968 -0.0308779667045
# -0.983967935872 -1.0 -0.0448254731771
# -0.987975951904 -0.995991983968 -0.0308779667045
# ...
